# %% [markdown]
# ### Importing Libraries and the Dataset

# %%
import pandas as pd
import numpy as np
import warnings

# Visualization
import matplotlib.pyplot as plt
import seaborn as sns
from pprint import pprint
# %matplotlib inline
from matplotlib.lines import Line2D

# Modelling
from sklearn.preprocessing import StandardScaler
import tensorflow as tf

warnings.filterwarnings("ignore")

# %%
filepath = 'Data/CountriesOnly.csv'

df = pd.read_csv(filepath, encoding = 'unicode_escape')
df = df.drop(['Unnamed: 0', 'Unnamed: 14'], axis = 1)

# Removing rows where country=World
worldDf = df[(df['country'] == 'World')].index
df.drop(worldDf , inplace=True)
df.head()
# Out:
#    country UNRegion  year           record      cropLand    grazingLand  \
# 0  Armenia     Asia  1992     BiocapPerCap  1.611286e-01       0.135023
# 1  Armenia     Asia  1992     BiocapTotGHA  5.558130e+05  465763.337400
# 2  Armenia     Asia  1992     EFConsPerCap  3.909225e-01       0.189137
# 3  Armenia     Asia  1992     EFConsTotGHA  1.348487e+06  652429.066600
# 4  Armenia     Asia  1992  EFExportsPerCap  1.124910e-03       0.002283
#
#       forestLand  fishingGround    builtupLand        carbon         total  \
# 0       0.083836       0.013718       0.033669  0.000000e+00  4.273741e-01
# 1  289190.662300   47320.224590  116139.598200  0.000000e+00  1.474227e+06
# 2       0.000001       0.004138       0.033669  1.112225e+00  1.730092e+00
# 3       4.327841   14272.803690  116139.598200  3.836620e+06  5.967954e+06
# 4       0.000000       0.000438       0.000000  4.819043e-02  5.203676e-02
#
#        GDP  population  countryCode
# 0  949.033   3449000.0          1.0
# 1  949.033   3449000.0          1.0
# 2  949.033   3449000.0          1.0
# 3  949.033   3449000.0          1.0
# 4  949.033   3449000.0          1.0

# %%
print("Number of countries: ", len(df.country.unique()))
# Out:
# Number of countries:  203

# %%
df[(df['country'] == 'South Africa') & (df['year'] == 2011)]
# Out:
#             country UNRegion  year           record  cropLand  grazingLand  \
# 69200  South Africa   Africa  2011     BiocapPerCap       NaN          NaN
# 69201  South Africa   Africa  2011     BiocapTotGHA       NaN          NaN
# 69202  South Africa   Africa  2011     EFConsPerCap       NaN          NaN
# 69203  South Africa   Africa  2011     EFConsTotGHA       NaN          NaN
# 69204  South Africa   Africa  2011  EFExportsPerCap       NaN          NaN
# 69205  South Africa   Africa  2011  EFExportsTotGHA       NaN          NaN
# 69206  South Africa   Africa  2011  EFImportsPerCap       NaN          NaN
# 69207  South Africa   Africa  2011  EFImportsTotGHA       NaN          NaN
# 69208  South Africa   Africa  2011     EFProdPerCap       NaN          NaN
# 69209  South Africa   Africa  2011     EFProdTotGHA       NaN          NaN
#
#        forestLand  fishingGround  builtupLand  carbon         total     GDP  \
# 69200         NaN            NaN          NaN     NaN  1.070094e+00  7493.3
# 69201         NaN            NaN          NaN     NaN  5.589881e+07  7493.3
# 69202         NaN            NaN          NaN     NaN  3.399956e+00  7493.3
# 69203         NaN            NaN          NaN     NaN  1.776045e+08  7493.3
# 69204         NaN            NaN          NaN     NaN  9.496150e-01  7493.3
# 69205         NaN            NaN          NaN     NaN  4.960532e+07  7493.3
# 69206         NaN            NaN          NaN     NaN  6.722535e-01  7493.3
# 69207         NaN            NaN          NaN     NaN  3.511671e+07  7493.3
# 69208         NaN            NaN          NaN     NaN  3.677318e+00  7493.3
# 69209         NaN            NaN          NaN     NaN  1.920931e+08  7493.3
#
#        population  countryCode
# 69200  52237000.0        202.0
# 69201  52237000.0        202.0
# 69202  52237000.0        202.0
# 69203  52237000.0        202.0
# 69204  52237000.0        202.0
# 69205  52237000.0        202.0
# 69206  52237000.0        202.0
# 69207  52237000.0        202.0
# 69208  52237000.0        202.0
# 69209  52237000.0        202.0

# %% [markdown]
# ### Removing null values

# %%
df.isna().sum()
# Out:
# country              0
# UNRegion           290
# year                 0
# record               0
# cropLand         25040
# grazingLand      25040
# forestLand       25040
# fishingGround    25040
# builtupLand      25040
# carbon           25040
# total                0
# GDP              21140
# population           0
# countryCode       5150
# dtype: int64

# %%
# Remove rows where all mentioned columns are null
df = df.dropna(subset=['cropLand', 'grazingLand', 'forestLand', 'fishingGround', 'builtupLand', 'carbon'], how='all')
df.isna().sum()
# Out:
# country              0
# UNRegion           170
# year                 0
# record               0
# cropLand             0
# grazingLand          0
# forestLand           0
# fishingGround        0
# builtupLand          0
# carbon               0
# total                0
# GDP              13080
# population           0
# countryCode       1650
# dtype: int64

# %% [markdown]
# ### Statistical Analysis

# %%
print("Statistical summary of each colums in the dataset:")
df.describe().T.style.background_gradient(axis=None)
# Out:
# Statistical summary of each colums in the dataset:
# <style type="text/css">
# #T_25f4c_row0_col0, #T_25f4c_row0_col1, #T_25f4c_row0_col2, #T_25f4c_row0_col3, #T_25f4c_row0_col4, #T_25f4c_row0_col5, #T_25f4c_row0_col6, #T_25f4c_row0_col7, #T_25f4c_row1_col0, #T_25f4c_row1_col1, #T_25f4c_row1_col3, #T_25f4c_row1_col4, #T_25f4c_row1_col5, #T_25f4c_row1_col6, #T_25f4c_row2_col0, #T_25f4c_row2_col1, #T_25f4c_row2_col2, #T_25f4c_row2_col3, #T_25f4c_row2_col4, #T_25f4c_row2_col5, #T_25f4c_row2_col6, #T_25f4c_row3_col0, #T_25f4c_row3_col1, #T_25f4c_row3_col3, #T_25f4c_row3_col4, #T_25f4c_row3_col5, #T_25f4c_row3_col6, #T_25f4c_row4_col0, #T_25f4c_row4_col1, #T_25f4c_row4_col2, #T_25f4c_row4_col3, #T_25f4c_row4_col4, #T_25f4c_row4_col5, #T_25f4c_row4_col6, #T_25f4c_row5_col0, #T_25f4c_row5_col1, #T_25f4c_row5_col2, #T_25f4c_row5_col3, #T_25f4c_row5_col4, #T_25f4c_row5_col5, #T_25f4c_row5_col6, #T_25f4c_row6_col0, #T_25f4c_row6_col1, #T_25f4c_row6_col3, #T_25f4c_row6_col4, #T_25f4c_row6_col5, #T_25f4c_row6_col6, #T_25f4c_row7_col0, #T_25f4c_row7_col3, #T_25f4c_row7_col4, #T_25f4c_row7_col5, #T_25f4c_row7_col6, #T_25f4c_row8_col0, #T_25f4c_row8_col1, #T_25f4c_row8_col2, #T_25f4c_row8_col3, #T_25f4c_row8_col4, #T_25f4c_row8_col5, #T_25f4c_row8_col6, #T_25f4c_row8_col7, #T_25f4c_row9_col0, #T_25f4c_row9_col3, #T_25f4c_row9_col4, #T_25f4c_row9_col5, #T_25f4c_row10_col0, #T_25f4c_row10_col1, #T_25f4c_row10_col2, #T_25f4c_row10_col3, #T_25f4c_row10_col4, #T_25f4c_row10_col5, #T_25f4c_row10_col6, #T_25f4c_row10_col7 {
#   background-color: #fff7fb;
#   color: #000000;
# }
# #T_25f4c_row1_col2, #T_25f4c_row7_col1, #T_25f4c_row9_col1, #T_25f4c_row9_col6 {
#   background-color: #fef6fb;
#   color: #000000;
# }
# #T_25f4c_row1_col7 {
#   background-color: #e7e3f0;
#   color: #000000;
# }
# #T_25f4c_row2_col7 {
#   background-color: #faf2f8;
#   color: #000000;
# }
# #T_25f4c_row3_col2 {
#   background-color: #fef6fa;
#   color: #000000;
# }
# #T_25f4c_row3_col7 {
#   background-color: #c9cee4;
#   color: #000000;
# }
# #T_25f4c_row4_col7, #T_25f4c_row5_col7 {
#   background-color: #fbf3f9;
#   color: #000000;
# }
# #T_25f4c_row6_col2 {
#   background-color: #fcf4fa;
#   color: #000000;
# }
# #T_25f4c_row6_col7 {
#   background-color: #167bb6;
#   color: #f1f1f1;
# }
# #T_25f4c_row7_col2 {
#   background-color: #faf3f9;
#   color: #000000;
# }
# #T_25f4c_row7_col7 {
#   background-color: #023858;
#   color: #f1f1f1;
# }
# #T_25f4c_row9_col2 {
#   background-color: #fbf4f9;
#   color: #000000;
# }
# #T_25f4c_row9_col7 {
#   background-color: #cccfe5;
#   color: #000000;
# }
# </style>
# <table id="T_25f4c_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >count</th>
#       <th class="col_heading level0 col1" >mean</th>
#       <th class="col_heading level0 col2" >std</th>
#       <th class="col_heading level0 col3" >min</th>
#       <th class="col_heading level0 col4" >25%</th>
#       <th class="col_heading level0 col5" >50%</th>
#       <th class="col_heading level0 col6" >75%</th>
#       <th class="col_heading level0 col7" >max</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_25f4c_level0_row0" class="row_heading level0 row0" >year</th>
#       <td id="T_25f4c_row0_col0" class="data row0 col0" >68810.000000</td>
#       <td id="T_25f4c_row0_col1" class="data row0 col1" >1991.792327</td>
#       <td id="T_25f4c_row0_col2" class="data row0 col2" >16.656370</td>
#       <td id="T_25f4c_row0_col3" class="data row0 col3" >1961.000000</td>
#       <td id="T_25f4c_row0_col4" class="data row0 col4" >1978.000000</td>
#       <td id="T_25f4c_row0_col5" class="data row0 col5" >1993.000000</td>
#       <td id="T_25f4c_row0_col6" class="data row0 col6" >2006.000000</td>
#       <td id="T_25f4c_row0_col7" class="data row0 col7" >2018.000000</td>
#     </tr>
#     <tr>
#       <th id="T_25f4c_level0_row1" class="row_heading level0 row1" >cropLand</th>
#       <td id="T_25f4c_row1_col0" class="data row1 col0" >68810.000000</td>
#       <td id="T_25f4c_row1_col1" class="data row1 col1" >7123690.501634</td>
#       <td id="T_25f4c_row1_col2" class="data row1 col2" >35846091.597266</td>
#       <td id="T_25f4c_row1_col3" class="data row1 col3" >0.000000</td>
#       <td id="T_25f4c_row1_col4" class="data row1 col4" >0.303390</td>
#       <td id="T_25f4c_row1_col5" class="data row1 col5" >2.854986</td>
#       <td id="T_25f4c_row1_col6" class="data row1 col6" >2091372.333750</td>
#       <td id="T_25f4c_row1_col7" class="data row1 col7" >838039968.300000</td>
#     </tr>
#     <tr>
#       <th id="T_25f4c_level0_row2" class="row_heading level0 row2" >grazingLand</th>
#       <td id="T_25f4c_row2_col0" class="data row2 col0" >68810.000000</td>
#       <td id="T_25f4c_row2_col1" class="data row2 col1" >2948037.931241</td>
#       <td id="T_25f4c_row2_col2" class="data row2 col2" >13892141.617216</td>
#       <td id="T_25f4c_row2_col3" class="data row2 col3" >0.000000</td>
#       <td id="T_25f4c_row2_col4" class="data row2 col4" >0.075123</td>
#       <td id="T_25f4c_row2_col5" class="data row2 col5" >2.526463</td>
#       <td id="T_25f4c_row2_col6" class="data row2 col6" >654475.049700</td>
#       <td id="T_25f4c_row2_col7" class="data row2 col7" >211503992.800000</td>
#     </tr>
#     <tr>
#       <th id="T_25f4c_level0_row3" class="row_heading level0 row3" >forestLand</th>
#       <td id="T_25f4c_row3_col0" class="data row3 col0" >68810.000000</td>
#       <td id="T_25f4c_row3_col1" class="data row3 col1" >7187801.073543</td>
#       <td id="T_25f4c_row3_col2" class="data row3 col2" >51190282.169679</td>
#       <td id="T_25f4c_row3_col3" class="data row3 col3" >0.000000</td>
#       <td id="T_25f4c_row3_col4" class="data row3 col4" >0.152119</td>
#       <td id="T_25f4c_row3_col5" class="data row3 col5" >3.348697</td>
#       <td id="T_25f4c_row3_col6" class="data row3 col6" >1493719.452000</td>
#       <td id="T_25f4c_row3_col7" class="data row3 col7" >1495330918.000000</td>
#     </tr>
#     <tr>
#       <th id="T_25f4c_level0_row4" class="row_heading level0 row4" >fishingGround</th>
#       <td id="T_25f4c_row4_col0" class="data row4 col0" >68810.000000</td>
#       <td id="T_25f4c_row4_col1" class="data row4 col1" >1826863.672942</td>
#       <td id="T_25f4c_row4_col2" class="data row4 col2" >8843892.727248</td>
#       <td id="T_25f4c_row4_col3" class="data row4 col3" >0.000000</td>
#       <td id="T_25f4c_row4_col4" class="data row4 col4" >0.032527</td>
#       <td id="T_25f4c_row4_col5" class="data row4 col5" >3.583375</td>
#       <td id="T_25f4c_row4_col6" class="data row4 col6" >248713.222025</td>
#       <td id="T_25f4c_row4_col7" class="data row4 col7" >173139105.800000</td>
#     </tr>
#     <tr>
#       <th id="T_25f4c_level0_row5" class="row_heading level0 row5" >builtupLand</th>
#       <td id="T_25f4c_row5_col0" class="data row5 col0" >68810.000000</td>
#       <td id="T_25f4c_row5_col1" class="data row5 col1" >735921.728254</td>
#       <td id="T_25f4c_row5_col2" class="data row5 col2" >5923105.976690</td>
#       <td id="T_25f4c_row5_col3" class="data row5 col3" >0.000000</td>
#       <td id="T_25f4c_row5_col4" class="data row5 col4" >0.000000</td>
#       <td id="T_25f4c_row5_col5" class="data row5 col5" >0.033122</td>
#       <td id="T_25f4c_row5_col6" class="data row5 col6" >59472.120370</td>
#       <td id="T_25f4c_row5_col7" class="data row5 col7" >171544177.500000</td>
#     </tr>
#     <tr>
#       <th id="T_25f4c_level0_row6" class="row_heading level0 row6" >carbon</th>
#       <td id="T_25f4c_row6_col0" class="data row6 col0" >68810.000000</td>
#       <td id="T_25f4c_row6_col1" class="data row6 col1" >13720443.665710</td>
#       <td id="T_25f4c_row6_col2" class="data row6 col2" >108425107.933827</td>
#       <td id="T_25f4c_row6_col3" class="data row6 col3" >0.000000</td>
#       <td id="T_25f4c_row6_col4" class="data row6 col4" >0.021996</td>
#       <td id="T_25f4c_row6_col5" class="data row6 col5" >1.365989</td>
#       <td id="T_25f4c_row6_col6" class="data row6 col6" >1027717.474500</td>
#       <td id="T_25f4c_row6_col7" class="data row6 col7" >3909964593.000000</td>
#     </tr>
#     <tr>
#       <th id="T_25f4c_level0_row7" class="row_heading level0 row7" >total</th>
#       <td id="T_25f4c_row7_col

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 68810 entries, 0 to 94419
# Data columns (total 14 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   country        68810 non-null  object
#  1   UNRegion       68640 non-null  object
#  2   year           68810 non-null  int64
#  3   record         68810 non-null  object
#  4   cropLand       68810 non-null  float64
#  5   grazingLand    68810 non-null  float64
#  6   forestLand     68810 non-null  float64
#  7   fishingGround  68810 non-null  float64
#  8   builtupLand    68810 non-null  float64
#  9   carbon         68810 non-null  float64
#  10  total          68810 non-null  float64
#  11  GDP            55730 non-null  float64
#  12  population     68810 non-null  float64
#  13  countryCode    67160 non-null  float64
# dtypes: float64(10), int64(1), object(3)
# memory usage: 7.9+ MB

# %%
shape = df.shape
print("Shape of Dataset is", shape, "\n")
print("---------------------------------")
print("Types of Data Attributes:")
print(df.dtypes, "\n")
# Out:
# Shape of Dataset is (68810, 14)
#
# ---------------------------------
# Types of Data Attributes:
# country           object
# UNRegion          object
# year               int64
# record            object
# cropLand         float64
# grazingLand      float64
# forestLand       float64
# fishingGround    float64
# builtupLand      float64
# carbon           float64
# total            float64
# GDP              float64
# population       float64
# countryCode      float64
# dtype: object

# %%
# Checking for duplicate values
df.duplicated().unique()
# Out:
# array([False])

# %% [markdown]
# ### Ecological Debtor and Creditor - df_classify
#
# - <code>bioTotal</code> is the BioCapTotGHA record
# - <code>ecoTotal</code> is the sum of all records for EcoTotGHA under each record type
#
# ex: For Armenia in 1961 under cropLand, <code>ecoTotal = cropLand(EFConsTotGHA) + cropLand(EFExportsTotGHA) + cropLand(EFImportsTotGHA) + cropLand(EFProdTotGHA) </code>

# %%
# Defining the EQF for each resource type
crop_eqf = 2.51
graze_eqf = 0.46
forest_eqf = 1.26
fishing_eqf = 0.37
carbon_eqf = 1.26
builtup_eqf = 2.51

biocapacity_records = ['BiocapTotGHA']
ecological_records = ['EFConsTotGHA','EFExportsTotGHA', 'EFImportsTotGHA', 'EFProdTotGHA']

biototal = 0
ecototal = 0
df_footprint = pd.DataFrame(columns=['country','year','record','bioTotal','ecoTotal'])

id_group=df.groupby(['country','year'])
id_group

landType = ['cropLand', 'grazingLand', 'forestLand', 'fishingGround', 'builtupLand', 'carbon']

for l in landType:
    for g_idx, group in id_group:
        biototal = 0
        ecototal = 0
        for r_idx, row in group.iterrows():
            if row['record'] in biocapacity_records:
                biototal = biototal + row[l]
            elif row['record'] in ecological_records:
                ecototal = ecototal + row[l]

        df2 = {'country': row['country'], 'countryCode': row['countryCode'] , 'year': row['year'], 'record': l, 'bioTotal': biototal, 'ecoTotal': ecototal}
        df_footprint = df_footprint.append(df2, ignore_index = True)

df_footprint = df_footprint.groupby(['country'], as_index=False).apply(pd.DataFrame.sort_values, 'year').reset_index()
df_footprint = df_footprint.drop(['level_0', 'level_1'], axis = 1)
df_footprint
# Out:
#            country  year         record      bioTotal      ecoTotal  \
# 0      Afghanistan  1961       cropLand  4.990785e+06  1.010593e+07
# 1      Afghanistan  1961  fishingGround  0.000000e+00  9.706928e+02
# 2      Afghanistan  1961    grazingLand  6.212850e+06  1.064433e+07
# 3      Afghanistan  1961    builtupLand  2.722616e+05  5.445231e+05
# 4      Afghanistan  1961         carbon  0.000000e+00  5.596314e+05
# ...            ...   ...            ...           ...           ...
# 41281     Zimbabwe  2018  fishingGround  1.425158e+05  2.284124e+05
# 41282     Zimbabwe  2018    grazingLand  4.357868e+06  8.762956e+06
# 41283     Zimbabwe  2018       cropLand  2.203482e+06  6.553660e+06
# 41284     Zimbabwe  2018    builtupLand  3.350453e+05  6.700907e+05
# 41285     Zimbabwe  2018         carbon  0.000000e+00  1.239203e+07
#
#        countryCode
# 0              2.0
# 1              2.0
# 2              2.0
# 3              2.0
# 4              2.0
# ...            ...
# 41281        181.0
# 41282        181.0
# 41283        181.0
# 41284        181.0
# 41285        181.0
#
# [41286 rows x 6 columns]

# %% [markdown]
# - <code>bioFootprint</code> is the bioTotal multiplied with the equivalence value from the above cell
# - <code>ecoFootprint</code> is calculated similarly

# %%
for index, row in df_footprint.iterrows():
    if df_footprint.at[index, 'record'] == 'cropLand':
        df_footprint.at[index, 'bioFootprint'] = df_footprint.at[index, 'bioTotal'] * crop_eqf
        df_footprint.at[index, 'ecoFootprint'] = df_footprint.at[index, 'ecoTotal'] * crop_eqf
    elif df_footprint.at[index, 'record'] == 'fishingGround':
        df_footprint.at[index, 'bioFootprint'] = df_footprint.at[index, 'bioTotal'] * fishing_eqf
        df_footprint.at[index, 'ecoFootprint'] = df_footprint.at[index, 'ecoTotal'] * fishing_eqf
    elif df_footprint.at[index, 'record'] == 'forestLand':
        df_footprint.at[index, 'bioFootprint'] = df_footprint.at[index, 'bioTotal'] * forest_eqf
        df_footprint.at[index, 'ecoFootprint'] = df_footprint.at[index, 'ecoTotal'] * forest_eqf
    elif df_footprint.at[index, 'record'] == 'grazingLand':
        df_footprint.at[index, 'bioFootprint'] = df_footprint.at[index, 'bioTotal'] * graze_eqf
        df_footprint.at[index, 'ecoFootprint'] = df_footprint.at[index, 'ecoTotal'] * graze_eqf
    if df_footprint.at[index, 'record'] == 'builtupLand':
        df_footprint.at[index, 'bioFootprint'] = df_footprint.at[index, 'bioTotal'] * builtup_eqf
        df_footprint.at[index, 'ecoFootprint'] = df_footprint.at[index, 'ecoTotal'] * builtup_eqf
    elif df_footprint.at[index, 'record'] == 'carbon':
        df_footprint.at[index, 'bioFootprint'] = df_footprint.at[index, 'bioTotal'] * carbon_eqf
        df_footprint.at[index, 'ecoFootprint'] = df_footprint.at[index, 'ecoTotal'] * carbon_eqf

# %%
df_footprint
df_footprint.to_csv('Data/NEW/Footprint.csv')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Input In [12], in <cell line: 2>()
#       1 df_footprint
# ----> 2 df_footprint.to_csv('Data/NEW/Footprint.csv')
#
# File ~\Anaconda3\lib\site-packages\pandas\core\generic.py:3466, in NDFrame.to_csv(self, path_or_buf, sep, na_rep, float_format, columns, header, index, index_label, mode, encoding, compression, quoting, quotechar, line_terminator, chunksize, date_format, doublequote, escapechar, decimal, errors, storage_options)
#    3455 df = self if isinstance(self, ABCDataFrame) else self.to_frame()
#    3457 formatter = DataFrameFormatter(
#    3458     frame=df,
#    3459     header=header,
#    (...)
#    3463     decimal=decimal,
#    3464 )
# -> 3466 return DataFrameRenderer(formatter).to_csv(
#    3467     path_or_buf,
#    3468     line_terminator=line_terminator,
#    3469     sep=sep,
#    3470     encoding=encoding,
#    3471     errors=errors,
#    3472     compression=compression,
#    3473     quoting=quoting,
#    3474     columns=columns,
#    3475     index_label=index_label,
#    3476     mode=mode,
#    3477     chunksize=chunksize,
#    3478     quotechar=quotechar,
#    3479     date_format=date_format,
#    3480     doublequote=doublequote,
#    3481     escapechar=escapechar,
#    3482     storage_options=storage_options,
#    3483 )
#
# File ~\Anaconda3\lib\site-packages\pandas\io\formats\format.py:1105, in DataFrameRenderer.to_csv(self, path_or_buf, encoding, sep, columns, index_label, mode, compression, quoting, quotechar, line_terminator, chunksize, date_format, doublequote, escapechar, errors, storage_options)
#    1084     created_buffer = False
#    1086 csv_formatter = CSVFormatter(
#    1087     path_or_buf=path_or_buf,
#    1088     line_terminator=line_terminator,
#    (...)
#    1103     formatter=self.fmt,
#    1104 )
# -> 1105 csv_formatter.save()
#    1107 if created_buffer:
#    1108     assert isinstance(path_or_buf, StringIO)
#
# File ~\Anaconda3\lib\site-packages\pandas\io\formats\csvs.py:237, in CSVFormatter.save(self)
#     233 """
#     234 Create the writer & save.
#     235 """
#     236 # apply compression and byte/text conversion
# --> 237 with get_handle(
#     238     self.filepath_or_buffer,
#     239     self.mode,
#     240     encoding=self.encoding,
#     241     errors=self.errors,
#     242     compression=self.compression,
#     243     storage_options=self.storage_options,
#     244 ) as handles:
#     245
#     246     # Note: self.encoding is irrelevant here
#     247     self.writer = csvlib.writer(
#     248         handles.handle,  # type: ignore[arg-type]
#     249         lineterminator=self.line_terminator,
#    (...)
#     254         quotechar=self.quotechar,
#     255     )
#     257     self._save()
#
# File ~\Anaconda3\lib\site-packages\pandas\io\common.py:702, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     697 elif isinstance(handle, str):
#     698     # Check whether the filename is to be opened in binary mode.
#     699     # Binary mode does not support 'encoding' and 'newline'.
#     700     if ioargs.encoding and "b" not in ioargs.mode:
#     701         # Encoding
# --> 702         handle = open(
#     703             handle,
#     704             ioargs.mode,
#     705             encoding=ioargs.encoding,
#     706             errors=errors,
#     707             newline="",
#     708         )
#     709     else:
#     710         # Binary mode
#     711         handle = open(handle, ioargs.mode)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'Data/NEW/Footprint.csv'

# %% [markdown]
# - Summing up the <code>bioTotal</code> and <code>ecoTotal</code> across all land types grouped by country and year
# - A country is then classified as an <b>ecological creditor</b> if their <code>bioFootprint > ecoFootprint</code> and an <b>ecological debtor</b> if their <code>bioFootprint < ecoFootprint</code>

# %%
df_classify = pd.DataFrame(columns=['country','year','footprintType'])

ecoF = 0
bioF = 0

id_group=df_footprint.groupby(['country','year'])
id_group

for g_idx, group in id_group:
    for r_idx, row in group.iterrows():
        bioF = bioF + row['bioFootprint']
        ecoF = ecoF + row['ecoFootprint']
        
    if bioF > ecoF:
        df2 = {'country': row['country'], 'year': row['year'], 'bioTot': bioF, 'ecoTot': ecoF, 'footprintType': 'Creditor'}
    else:
        df2 = {'country': row['country'], 'year': row['year'], 'bioTot': bioF, 'ecoTot': ecoF, 'footprintType': 'Debter'}
    
    df_classify = df_classify.append(df2, ignore_index = True)

# %%
df_classify

# %%
df_classify.to_csv('Data/Modelling/Classification.csv')
df_footprint.to_csv('Data/Modelling/PredictionDataset.csv')
df_classify

# %% [markdown]
# ### Making the dataset ready for modelling

# %%
def navalues(data):
    cols = data.columns
    for j in cols:
        for i in range(0,len(data)):
             if data[j][i].isna():
                data[j][i] = data[j][i-1]
                
def scale(df):
    sc = StandardScaler()
    df[['bioTotal', 'ecoTotal', 'bioFootprint', 'ecoFootprint']] = sc.fit_transform(df[['bioTotal', 'ecoTotal', 'bioFootprint', 'ecoFootprint']])
    return df

def reverse_scale(df):
    sc = StandardScaler()
    return sc.inverse_transform(df)

def encode(df):
    if 'country' in df.columns.unique():
        df = df.drop(['country'], axis=1)
    if 'record' in df.columns.unique():
        df = pd.get_dummies(df, columns=["record"])
    return df

def prepare_timeseries(df, record):
    return df.set_index(['year'])

def prepareCountryDf(df, countryCode):
    df = df.loc[df['countryCode'] == countryCode]
    return df

# %%
df_footprint

# %%
df_others = encode(scale(df_footprint))
df_others.index = df_others.year
df_others = df_others.drop(['year'], 1)
print("Shape of the dataset: ", df_others.shape)
print("-----------------------------------")
df_others.head()

# %%
df_footprint.to_csv('Data/NEW/Footprint.csv')

# %% [markdown]
# ### Correlation Analysis

# %%
plt.figure(figsize=(8,6))
ax = sns.heatmap(df_footprint.select_dtypes(include='number').corr(), annot = True, linewidth=0.5, fmt='0.1f', cmap = 'RdBu_r')
ax.set_ylim(sorted(ax.get_xlim(), reverse=True))
plt.show()

# %%
df_footprint.corr()

# %% [markdown]
# ## Modeling

# %%
import math
import matplotlib.pyplot as plt
import numpy as np
from numpy.random import seed
seed(1)
import pandas as pd
import statsmodels.api as sm
import statsmodels.formula.api as smf
import tensorflow
tensorflow.random.set_seed(1)
from tensorflow.python.keras.layers import Dense
from tensorflow.keras.layers import Dropout
from tensorflow.python.keras.models import Sequential
from tensorflow.python.keras.wrappers.scikit_learn import KerasRegressor
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_squared_error
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler

# %%
model = Sequential()
model.add(Dense(8, input_dim=10, kernel_initializer='normal', activation='relu'))
model.add(Dense(2670, activation='relu'))
model.add(Dense(1, activation='linear'))
model.summary()

# %%
X = df_others.drop(["ecoFootprint"], 1)
y = df_others["ecoFootprint"]

X_train, X_val, y_train, y_val = train_test_split(X, y, test_size=0.1, random_state=21)

X_train = np.asarray(X_train).astype('float32')
X_val = np.asarray(X_val).astype('float32')
y_train = np.asarray(y_train).astype('float32')
y_val = np.asarray(y_val).astype('float32')

# %%
model.compile(loss='mse', optimizer='adam', metrics=['mse','mae'])
history=model.fit(X_train, y_train, epochs=10, batch_size=150, verbose=1, validation_split=0.2)
predictions = model.predict(X_val)

# %%
predictions

# %%
mean_absolute_error(y_val, predictions)

# %%
math.sqrt(mean_squared_error(y_val, predictions))

# %%
np.mean(y_val)

# %%
np.mean(predictions)

# %% [markdown]
# ### LSTM

# %%
df_modeling_ts = df_modeling
df_modeling_ts.index = df_modeling_ts.year
df_modeling_ts = df_modeling.drop(['year'], axis=1)
df_modeling_ts

# %%
from matplotlib import pyplot

values = df_modeling_ts.values
# specify columns to plot
groups = [0, 1, 2, 3, 5, 6, 7]
i = 1
# plot each column
pyplot.figure()
for group in groups:
    pyplot.subplot(len(groups), 1, i)
    pyplot.plot(values[:, group])
    pyplot.title(df_modeling_ts.columns[group], y=0.5, loc='right')
    i += 1
pyplot.show()
